# %% [markdown]
# # Final Project FP-7:  The GM's blueprint: Quantifying the value of positional units to maximize win probability in the NFL
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
# # Quantifying the value of positional units to maximize win probability in the NFL
#
#
# * **Name**:  Baier, Jonas
# * **Student number**:  0490373562
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The primary objective of this multivariate logistic regression analysis is to rigorously determine the marginal contribution of a comprehensive set of offensive, defensive, and special teams efficiency metrics to the probability of winning an NFL game. The analysis will conclude with a data-driven prioritization strategy for a General Manager, detailing which units or metrics (e.g., Passing Efficiency vs. Red Zone Defense) show the highest correlation with victory and therefore deserve the largest cap allocation and draft capital, and which can be safely deprioritized.
# * The key **dependent variable** (DV) is the **game result** , operationalized as the home team’s margin of victory. In the machine learning section, this outcome is recoded as a binary indicator of a home win.
# * The key **independent variable(s) (IVs)** are game-level differentials (Home Team Value - Away Team Value) aggregated from play-by-play data. These variables cover the spectrum of strategic decision-making:
# * Passing Offense : **Differential Passing EPA**
# * Running Offense : **Differential Rushing EPA**
# * Situational Offense : **Differential Red Zone Score %**
# * Defensive Pressure : **Differential Sack Rate**
# * Defensive Coverage : **Differential Defensive Pass EPA**
# * Turnover/Ball Security : **Differential Turnover Margin**
# * Situational Defense : **Differential 3rd Down Conversion %**
# * Special Teams : **Differential Field Goal EPA**
# * Game Control : **Differential Time of Possession (TOP)**
# * Discipline : **Differential Penalty Yards**
# * The raw Play-by-Play data contains over 5 Million cases (individual plays from 2017-2025). This will be aggregated into 2344 individual games. The analysis will calculate one dependent variable (DV) and ten comprehensive independent variables (IVs) from the raw data.
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data comes from the [NFL](https://nfl.com) dataset from the [nflverse-data repository](https://github.com/nflverse/nflverse-data/releases)
#
# The datasets are available for download [here](https://github.com/nflverse/nflverse-data/releases/tag/pbp).

# %%
import parse_data

# %%
df = parse_data.build_full_dataset("play_by_play")

# %%
df.describe()
# Out:
#         home_score   away_score   score_diff     home_win  diff_pass_epa  \
# count  2344.000000  2344.000000  2344.000000  2344.000000    2344.000000
# mean     23.779010    21.927474     1.851536     0.546075       0.004256
# std      10.154494     9.842457    14.300929     0.497979       0.464265
# min       0.000000     0.000000   -49.000000     0.000000      -1.589303
# 25%      17.000000    16.000000    -7.000000     0.000000      -0.306462
# 50%      24.000000    21.000000     2.000000     1.000000       0.000171
# 75%      30.000000    28.000000    10.000000     1.000000       0.300871
# max      70.000000    59.000000    50.000000     1.000000       2.159788
#
#        diff_rush_epa      diff_rz    diff_sack  diff_def_pass_epa  \
# count    2344.000000  2303.000000  2344.000000        2344.000000
# mean       -0.010811     0.013712     0.002400           0.004256
# std         0.288061     0.377507     0.059462           0.464265
# ...

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %% [markdown]
# This section summarizes the most important descriptive patterns in game outcomes and efficiency differentials.

# %%
import descriptive

# %%
descriptive.figure_1_score_distribution(df)
descriptive.figure_2_key_efficiency_relationship(df)

# %%
import classical

# %% [markdown]
# We test whether differences in turnovers and red zone efficiency lead to systematically different game outcomes.

# %%
classical.plot_turnover_margin(df)

# %%
classical.plot_passing_epa(df)

# %% [markdown]
# ___
#
# ## Machine Learning

# %%
import importlib
import machine
import improved

# %%
results = improved.run_improved_machine_learning(df)
improved.plot_improved_roc_curve(results["y_test"], results["y_prob"])

# %% [markdown]
# Figure 5 shows how accurately the improved model distinguishes between home wins and losses. The dashed diagonal line represents random guessing. The model’s curve rises steeply and remains well above this line, indicating strong predictive ability.
#
# The most important point is that the model correctly ranks games by win likelihood with high reliability. Even when the false positive rate is low, the true positive rate is already high, meaning the model identifies many actual wins while making relatively few incorrect win predictions. This demonstrates that the preprocessing step preserves, and may slightly improve, out-of-sample performance by reducing redundancy among correlated performance measures.

# %%
improved.plot_improved_feature_importance(results["model"], machine.FEATURES)

# %% [markdown]
# Figure 6 shows which performance measures contribute most to the dominant performance patterns learned by the model. Larger bars indicate variables that play a greater overall role in determining predictions.
#
# The figure shows that a small number of performance measures dominate, particularly turnover margin, penalties, rushing efficiency, and time of possession, with passing-related measures contributing as part of broader performance patterns. This indicates that winning is associated with clusters of related advantages rather than isolated statistics.
#
# For interpretation, the key takeaway is that team success reflects consistent advantages across a few core dimensions of performance. The model captures these structured patterns rather than relying on many independent or noisy indicators.
